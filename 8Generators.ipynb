# %% [markdown]
# Generators
#
# simpler way to create iterators
#
# They use the yield keyword to produce a series of values lazily,
#
# means they generate values on fly and do not store them in memory

# %%
def square(n):
    for i in range(3):
        yield i**2

# %%
for i in square(3):
    print(i)
# Out:
# 0
# 1
# 4

# %%
def my_generator():
    yield1
    yield2
    yield3
