# %% [markdown]
# Decorators
#
# powerful and flexible feature, allow to modify the behaviour of a function or class method
#
# commonly used to add functionality to functions or methods without modifying actual code

# %%
##Function copy
##closures
##decorators

# %%
#Function copy

def welcome():
    return 'welcome to the advance python course'

welcome()
# Out:
# 'welcome to the advance python course'
